# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("12")

# %% [markdown]
# # 関数からの複数の出力の取得

# %%
import numpy as np

data = np.array([[3, 0.53, 4.0753, 0.5],
              [18, 1.78, 6.6678, 2.1328],
              [19, 0.86, 1.5177, 3.6852],
              [20, 1.6, 3.6375, 8.5389],
              [21, 3, 4.7243, 10.157],
              [23, 6.11, 9.0698, 2.8739],
              [38, 2.54, 5.3002, 4.4508]])
v1 = np.copy(data[:,2])
v2 = np.copy(data[:,3])

# %% [markdown]
# 属性 shape を用いると、配列の shape を含む変数を生成できます。
# ```
# s = x.shape
# ```
# 変数 data の shape を含む、dshape という変数を作成しましょう。

# %%
check("q1")

# %% [markdown]
# 行列の shape 属性は、タプルになっています。タプルの個々の要素の値を取得するには、タプルの要素数だけの変数を用意します。
# ```
# xrow, xcol = x.shape
# ```
# 変数 data の行数と列数をそれぞれ含む変数 dr および dc を作成しましょう。

# %%
print(dr, dc)

# %%
check("q2")

# %%
np.argmax(v2)

# %% [markdown]
# ベクトルの最大値に対応するインデクス値は、関数 argmax を使用して特定できます。
# ```
# idx = np.argmax(x)
# ```
# ベクトル v2 の最大値とそれに対応するインデクス値をそれぞれ含む、変数 vMax および ivMax を作成しましょう。

# %%
print(vMax, ivMax)

# %%
check("q3")

# %% [markdown]
# argmax 関数を用いて得られたインデクス値を用いて最大値を抽出することもできます。
#
# argmin 関数を用いて、v2 の最小値を抽出してみましょう。

# %%
print(np.min(v2))
