# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("05")

# %% [markdown]
# # 配列の手動入力
#
# 単一の数値はスカラーと呼ばれます。
# 4 の値をもつ x という変数を作成しましょう。

# %%
x = 4

# %%
import numpy as np

# %% [markdown]
# np.array を使うと、複数の要素を持つ配列(ベクトル)を作成できます。

# %%
x = np.array([3,5])
x

# %% [markdown]
# 7, 9 の二つの値を持つ x という配列を作成しましょう。

# %%
check("q1")

# %% [markdown]
# shape という属性を見ると、配列の形がわかります。

# %%
x.shape

# %% [markdown]
# 要素数 2 の 1 次元配列であることがわかります。
#
# 1 次元の配列は、行でも列でもありません。`x.T` と書いても形は変わりません。行と列を区別した形が必要になったときは、次に出てくる 2 次元の配列を使います。

# %% [markdown]
# 複数の列を持つ行を , で結合すると、複数の行と列をもつ配列である行列を作成できます。行は全て同じ列の数にしないといけません。

# %%
x = np.array([[3,4,5],
 [6,7,8]])
x

# %% [markdown]
# 次の値を持つ x という行列を作成しましょう
# $$\begin{matrix}
# 5 & 6 & 7 \\
# 8 & 9 & 10 \\
# \end{matrix}
# $$

# %%
check("q2")

# %% [markdown]
# 計算結果を使って、ベクトルや行列を作ることもできます。

# %%
x = np.array([np.abs(-4), 4**2])
x

# %% [markdown]
# 最初の要素として $\sqrt{10}$ を 2 番目の要素として $\pi^2$ を含む x というベクトルを作成しましょう。

# %%
check("q3")
