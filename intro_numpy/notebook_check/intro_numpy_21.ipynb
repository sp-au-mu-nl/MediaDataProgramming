# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("21")

# %% [markdown]
# # for ループ

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

data = np.array([[0.53, 4.0753, np.nan],
              [1.78, 6.6678, 2.1328],
              [0.86, 1.5177, 3.6852],
              [1.6, 3.6375, 8.5389],
              [3, 4.7243, 10.157],
              [6.11, 9.0698, 2.8739],
              [2.54, 5.3002, 4.4508]])
element = ['Lithium',
'Argon',
'Potassium',
'Calcium',
'Scandium',
'Vanadium',
'Strontium',]
density = data[:,0]

# %% [markdown]
# このコードが実行されると、ループ カウンター (c) が値 (0、1、2) を順に辿るのに合わせて、ループ本体が 3 回実行されます。
# ```
# for c in range(3): # c はループカウンター
#   print(c) # 本体
# ```
#
# 下記のセルでコードをラップしてループにし、コードが 7 回実行されるようにします。
#
# ループ カウンターに idx という名前を付けます。ループの最初の実行で idx は 0 から始まり、連続する反復ごとに 1 ずつ増えます。

# %%
  plt.plot(idx,density[idx],'*')

# %%
check("q1")

# %% [markdown]
# density ベクトルが 7 個の要素をもつため、ループは 7 回実行されます。長さが不明なベクトルをループする場合は、関数 len を使用します。
# ```
# for idx in range(len(density)):
# ```
