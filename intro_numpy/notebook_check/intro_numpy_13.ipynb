# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("13")

# %% [markdown]
# # info の取得

# %%
import numpy as np

# %% [markdown]
# np.info を用いると、numpy の関数を用いるのに役立つ例と情報を得られます。
#
# 以下のタスクを完了するため、np.random.randint の情報を利用してみましょう。
#
# 次のような行列 x を作成しましょう。
#
# *   1 から 20 までの範囲のランダムな整数を含む
# *   5行
# *   7列

# %%
check("q1")

# %% [markdown]
# 関数などについては、[Numpy reference](https://numpy.org/doc/stable/reference/index.html#reference) で検索することもできます。
