# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("16")

# %% [markdown]
# # プロジェクト・電力使用量
#
# 電力データは electricity.pkl というファイルに保存されています。このファイルは dill を用いて保存したものです。
#
# このファイルを python に読み込みます。次に、usage を表示してみましょう。

# %%
import dill

# %%
# !wget https://github.com/slp-hu/MediaDataProgramming/raw/refs/heads/main/intro_numpy/data/electricity.pkl

# %%
dill.load_session('electricity.pkl')

# %%
usage

# %% [markdown]
# 変数 usage の 1 つは nan の値となっています。この値を 2.74 に置き換えましょう。

# %%
check("q1")

# %% [markdown]
# 住宅のデータは 1 列目に保存されています。usage の 1 列目を含む変数 res を作成しましょう。

# %%
check("q2")

# %% [markdown]
# 商業のデータと産業のデータはそれぞれ 2 列目と 3 列目に保存されています。usage の 2 列目と 3 列目を含む変数 comm および ind を作成します。

# %%
check("q3")

# %% [markdown]
# 使用量データは、1991年から2013年までの間に毎年収集されました。変数 yrs を作成して、指定した範囲でデータをプロットしましょう。
#
# まず、1991年から2013年までの年を表す yrs というベクトルを作成しましょう。

# %%
import numpy as np

# %%
check("q4")

# %% [markdown]
# ３列全てを含むプロットを作成しましょう。yrs を x 軸のデータとして使用します。以下のプロット仕様をこの順序で仕様します。
#
# 1.   res: 青(b) の破線(--)
# 2.   comm: 黒(k) の点線(:)
# 3.   ind: マゼンタ(m) の一点鎖線(-.)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# プロットにタイトル "July Electricity Usage" を追加しましょう。
#
# また、値 "res"、"comm"、および "ind" を含む凡例を作成しましょう。

# %% [markdown]
# 図を見ると、産業部門の電力使用量はかなり安定しているのが明らかで、住宅部門や商業部門ほどの変動はないように見受けられます。
