# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("06")

# %% [markdown]
# # 等間隔のベクトルの作成

# %%
import numpy as np

# %% [markdown]
# 以下のベクトルのように、等間隔の数値を含むベクトルを作成することはよくあります。

# %%
y = np.array([5, 6, 7, 8])
y

# %% [markdown]
# 値 1,2,3 をこの順序で含む x というベクトルを作成しましょう。

# %%
check("q1")

# %% [markdown]
# 長いベクトルの場合、数値を個々に入力することは現実的ではありません。等間隔のベクトルを作成するための簡潔な代替方法は、np.arange 関数を使用して開始点と「終了点の次の値」のみを指定することです。

# %%
y = np.arange(5,9)
y

# %% [markdown]
# 値 1,2,3,4 を含む x というベクトルを作成しましょう。

# %%
check("q2")

# %% [markdown]
# arange では、指定しないと間隔は 1 になりますが、以下のように間隔を指定できます。

# %%
x = np.arange(20,26+1,2)
x

# %% [markdown]
# 1 で始まり、5 で終わる、各要素の間隔が 0.5 の x というベクトルを作成しましょう。

# %%
check("q3")

# %% [markdown]
# ３で始まり、13 で終わる、各要素の間隔が 2 の x というベクトルを作成しましょう。

# %%
check("q4")

# %% [markdown]
# ベクトルに含める要素数がわかっていて、等間隔のベクトルを作成するときには、np.linspace を用います。

# %%
x = np.linspace(0,1,5)
x

# %% [markdown]
# 1 で始まり 10 で終わる、5 つの要素を含む x というベクトルを作成しましょう。

# %%
check("q5")

# %% [markdown]
# 1 次元のベクトルは、転置しても形が変わりません。行と列を区別した形にしたいときは、reshape で 2 次元の配列にします。

# %%
x = np.arange(1,4)
x.T

# %% [markdown]
# 1 から $2\pi$ までの 100 個の要素を持つ等間隔ベクトルを作成してみましょう。
