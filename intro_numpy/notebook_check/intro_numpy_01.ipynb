# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("01")

# %% [markdown]
# # コマンドの入力
#
# スクリプトを実行してみましょう。
# $3\times 5$ は
# ```
# 3*5
# ```
# と入力して Enter キーを押せば実行できます。

# %% [markdown]
# 代入先を指定しない限り、計算結果は _ (アンダースコア) という変数に代入されます。
# ```
# print(_)
# ```
# を実行してみましょう。

# %% [markdown]
# $ 3\times 5$ の結果を $m$ という変数に代入してみましょう。

# %%
check("q1")

# %% [markdown]
# python (numpy) では、$=$ は、代入演算子です。つまり、等号の右側の式が左側の変数に代入されるという意味です。
#
# $x = 3+4$ を入力すると、python では、まず $3+4$ を実行してから、結果を変数 $x$ に代入します。
# ```
# m = m + 1
# ```
# を実行したら $m$ はどのような値になるでしょうか? 確認してみましょう。

# %%
check("q2")

# %% [markdown]
# ウィンドウの左下の {} 変数というところをクリックすると、変数がすべて表示されていることがわかります。(_ は除く)
#
# 値 $m/2$ を持つ $y$ という変数を作成します。

# %%
check("q3")

# %% [markdown]
# google colab では、セルの最後の行の実行結果が表示されます。変数だけを入力すると、その値が表示されます。
# ```
# k = 6
# m = 3*k
# ```
# を実行してから、$y$ に変化があったかどうかを確かめてみてください。

# %%
check("q4")
