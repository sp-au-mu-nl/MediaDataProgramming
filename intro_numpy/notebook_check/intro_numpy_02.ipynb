# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("02")

# %% [markdown]
# # 変数の命名

# %%
a = 8

# %% [markdown]
# 英字もしくは _ (アンダースコア) で始まり、英字、_, 数字のみを含むものであれば、変数にはどんな名前でもつけられます。
#
# 変数名では、大文字と小文字も区別されます。
#
# $-2$ を $A$ に代入します。

# %%
check("q1")

# %% [markdown]
# 変数 $A$ と $a$ の両方が存在することを確認しましょう。
#
# 変数名は、何か意味のある名前にした方がプログラムが書きやすくなるでしょう。
#
# $\frac{a+A}{2}$ を計算します。その結果を $avgAa$ に代入しましょう。

# %%
check("q2")

# %% [markdown]
# 規約にしたがわない変数名は SyntaxError になります。
#
# $3sq=9$ を実行してみましょう。
