# %% [markdown]
# <a href="https://colab.research.google.com/github/slp-hu/MediaDataProgramming/blob/main/intro_numpy/notebook_check/intro_numpy_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 準備（最初に実行してください）
# !wget -q -O mdpcheck.py https://raw.githubusercontent.com/slp-hu/MediaDataProgramming/main/intro_numpy/check/mdpcheck.py
from mdpcheck import setup
check = setup("04")

# %% [markdown]
# # 関数および定数の利用

# %%
import numpy as np

# %% [markdown]
# numpy には、$\pi$ を表す np.pi などの組込定数があります。

# %%
a = np.pi
a

# %% [markdown]
# 表示される桁は一部であることに注意してください。
#
# $\pi/2$ の値をもつ x という変数を作成しましょう。

# %%
check("q1")

# %% [markdown]
# numpy には、abs(絶対値) や eig(固有値の計算)など、さまざまな組込関数が含まれています。

# %%
a = np.sin(-5)
a

# %% [markdown]
# 関数 sin を使用して、x の正弦を計算しましょう。その結果を y という変数に代入しましょう。

# %%
check("q2")

# %% [markdown]
# -9 の平方根を計算するような場合は、np.sqrt ではなく、np.emath.sqrt を使うと複素数の結果が得られます。

# %%
z = np.sqrt(-9)
print(z)
z = np.emath.sqrt(-9)
print(z)

# %% [markdown]
# 3j の j は虚数単位を表します。
# nan は Not a Number の略であり数でないオブジェクトを表します。
