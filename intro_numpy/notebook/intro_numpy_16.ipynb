# %% [markdown]
# <a href="https://colab.research.google.com/github/sp-au-mu-nl/MediaDataProgramming/blob/main/intro_numpy/notebook/intro_numpy_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # プロジェクト・電力使用量
#
# 電力データは electricity.pkl というファイルに保存されています。このファイルは dill を用いて保存したものです。
#
# このファイルを python に読み込みます。次に、usage を表示してみましょう。

# %%
import dill

# %%
# !wget https://github.com/sp-au-mu-nl/MediaDataProgramming/raw/refs/heads/main/intro_numpy/data/electricity.pkl
# Out:
# --2025-08-26 13:12:57--  https://github.com/sp-au-mu-nl/MediaDataProgramming/raw/refs/heads/main/intro_numpy/data/electricity.pkl
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sp-au-mu-nl/MediaDataProgramming/refs/heads/main/intro_numpy/data/electricity.pkl [following]
# --2025-08-26 13:12:58--  https://raw.githubusercontent.com/sp-au-mu-nl/MediaDataProgramming/refs/heads/main/intro_numpy/data/electricity.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6500 (6.3K) [application/octet-stream]
# Saving to: ‘electricity.pkl’
#
# electricity.pkl     100%[===================>]   6.35K  --.-KB/s    in 0s
#
# 2025-08-26 13:12:58 (58.1 MB/s) - ‘electricity.pkl’ saved [6500/6500]

# %%
dill.load_session('electricity.pkl')

# %%
usage
# Out:
# array([[3.0484, 2.5848, 2.6408],
#        [2.861 , 2.553 ,    nan],
#        [3.2602, 2.7084, 2.7345],
#        [3.342 , 2.8097, 2.8019],
#        [3.3555, 2.9167, 2.796 ],
#        [3.4234, 2.9299, 2.8579],
#        [3.5268, 3.1561, 2.8597],
#        [3.9185, 3.3057, 2.8757],
#        [3.9718, 3.4761, 2.9984],
#        [3.854 , 3.4748, 2.8998],
#        [3.8934, 3.5968, 2.6826],
#        [4.3127, 3.7088, 2.8427],
#        [4.2153, 3.7172, 2.8301],
#        [4.1711, 3.7257, 2.8542],
#        [4.6605, 3.9367, 2.8512],
#        [4.7528, 4.0497, 2.8671],
#        [4.4847, 3.9975, 2.8715],
#        [4.6216, 4.1299, 2.8487],
#        [4.4413, 3.9229, 2.5176],
#        [4.9899, 4.1266, 2.7653],
#        [4.9913, 4.1311, 2.8143],
#        [4.9864, 4.1463, 2.8135],
#        [4.627 , 4.1205, 2.7001]])

# %% [markdown]
# 変数 usage の 1 つは nan の値となっています。この値を 2.74 に置き換えましょう。

# %%
# Out:
# array([[3.0484, 2.5848, 2.6408],
#        [2.861 , 2.553 , 2.74  ],
#        [3.2602, 2.7084, 2.7345],
#        [3.342 , 2.8097, 2.8019],
#        [3.3555, 2.9167, 2.796 ],
#        [3.4234, 2.9299, 2.8579],
#        [3.5268, 3.1561, 2.8597],
#        [3.9185, 3.3057, 2.8757],
#        [3.9718, 3.4761, 2.9984],
#        [3.854 , 3.4748, 2.8998],
#        [3.8934, 3.5968, 2.6826],
#        [4.3127, 3.7088, 2.8427],
#        [4.2153, 3.7172, 2.8301],
#        [4.1711, 3.7257, 2.8542],
#        [4.6605, 3.9367, 2.8512],
#        [4.7528, 4.0497, 2.8671],
#        [4.4847, 3.9975, 2.8715],
#        [4.6216, 4.1299, 2.8487],
#        [4.4413, 3.9229, 2.5176],
#        [4.9899, 4.1266, 2.7653],
#        [4.9913, 4.1311, 2.8143],
#        [4.9864, 4.1463, 2.8135],
#        [4.627 , 4.1205, 2.7001]])

# %% [markdown]
# 住宅のデータは 1 列目に保存されています。usage の 1 列目を含む変数 res を作成しましょう。

# %%
# Out:
# array([3.0484, 2.861 , 3.2602, 3.342 , 3.3555, 3.4234, 3.5268, 3.9185,
#        3.9718, 3.854 , 3.8934, 4.3127, 4.2153, 4.1711, 4.6605, 4.7528,
#        4.4847, 4.6216, 4.4413, 4.9899, 4.9913, 4.9864, 4.627 ])

# %% [markdown]
# 商業のデータと産業のデータはそれぞれ 2 列目と 3 列目に保存されています。usage の 2 列目と 3 列目を含む変数 comm および ind を作成します。

# %% [markdown]
# 使用量データは、1991年から2013年までの間に毎年収集されました。変数 yrs を作成して、指定した範囲でデータをプロットしましょう。
#
# まず、1991年から2013年までの年を表す yrs というベクトルを作成しましょう。

# %%
import numpy as np
# Out:
# array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013])

# %% [markdown]
# ３列全てを含むプロットを作成しましょう。yrs を x 軸のデータとして使用します。以下のプロット仕様をこの順序で仕様します。
#
# 1.   res: 青(b) の破線(--)
# 2.   comm: 黒(k) の点線(:)
# 3.   ind: マゼンタ(m) の一点鎖線(-.)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# プロットにタイトル "July Electricity Usage" を追加しましょう。
#
# また、値 "res"、"comm"、および "ind" を含む凡例を作成しましょう。

# %% [markdown]
# 図を見ると、産業部門の電力使用量はかなり安定しているのが明らかで、住宅部門や商業部門ほどの変動はないように見受けられます。
